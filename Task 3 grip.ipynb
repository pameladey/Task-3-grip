# %% [markdown]
# **`PAMELA DEY`**
#
# ##TASK 3
#
#
# **Exploratory Data Analysis - Retail**
#
# *Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’*

# %% [markdown]
# **GRIP**
#
# @The Sparks Foundation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\pamel\Downloads\SampleSuperstore.csv")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9977 rows x 13 columns]

# %%
sns.heatmap(data_set.isnull(), cbar=False, yticklabels=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **From above we can see there is no missing values in the dataset.**

# %% [markdown]
# **Analysis using Pairplot of each column**
#
# **Based on Category**

# %%
sns.pairplot(data_set, hue = 'Category')

# %% [markdown]
# **Based on Region**

# %%
sns.pairplot(data_set, hue = 'Region')

# %% [markdown]
# **Based on Segment**

# %%
sns.pairplot(data_set, hue = 'Segment')

# %% [markdown]
# **Based on Sub-Category**

# %%
sns.pairplot(data_set, hue = 'Sub-Category')

# %% [markdown]
# **Exploratory Data Analysis**

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(data_set['Sales'],color='purple',label='Sales',shade=True,bw_adjust=20)
sns.kdeplot(data_set['Profit'],color='red',label='Profit',shade=True,bw_adjust=20)
plt.xlim([-100,1000])
plt.legend()

# %% [markdown]
# **CATEGORIES VS REGION**

# %%
plt.figure(figsize=(13,7))
plt.title('CATEGORIES VS REGION')
sns.countplot(x=data_set['Category'],hue=data_set['Region'],palette='mako')
plt.xticks()
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Furniture'),
#   Text(1, 0, 'Office Supplies'),
#   Text(2, 0, 'Technology')])

# %% [markdown]
# **Category VS Sub-Category**

# %%
plt.figure(figsize=(18,9))
plt.title('Category VS Sub-Category')
sns.countplot(x=data_set['Category'],hue=data_set['Sub-Category'],palette='mako')
plt.xticks()
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Furniture'),
#   Text(1, 0, 'Office Supplies'),
#   Text(2, 0, 'Technology')])

# %% [markdown]
# **Sales vs Profit**

# %%
plt.subplots(figsize=(10,6))
plt.scatter(data_set['Sales'],data_set['Profit'],color='blue', marker='.')
plt.xlabel('Sales')
plt.ylabel("Profit")
plt.title('Sales vs Profit',fontsize=20)
plt.show()

# %% [markdown]
# Most sales are less than USD$5k
#
# A significant number of transactions under USD$2.5k result in a loss.
#
# Larger sales above USD$2.5k are very likely to result in a profit.

# %%
# correlation matrix of the data
data_set.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
# covariance matrix of data
data_set.cov()
# Out:
#               Postal Code          Sales    Quantity    Discount  \
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228
# Quantity     9.104159e+02     278.459923    4.951113    0.003961
# Discount     3.868704e+02      -3.627228    0.003961    0.042622
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173
#
#                     Profit
# Postal Code -225045.849445
# Sales         69944.096586
# Quantity         34.534769
# Discount        -10.615173
# Profit        54877.798055

# %% [markdown]
# **Heatmap for Correlation**

# %%
sns.heatmap(data_set.corr(),annot= True,cmap = 'mako')
plt.figure(figsize=(14,7))

# %% [markdown]
# **From above Heatmap:**
#
# 1.Sales and Profit are Moderately Correlated.
#
# 2.Discount and Profit are Negatively Correlated.
#
# 3.Quantity and Profit are less Moderately Correlated.

# %%
sns.countplot(data_set['Category'])
plt.figure(figsize=(15,7))
# Out:
# c:\users\pamel\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data_set['Region'])
plt.figure(figsize=(12,6))
# Out:
# c:\users\pamel\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Count plot of each coloumn**

# %%
fig, axs = plt.subplots(nrows = 2,ncols = 2,figsize = (12,6))
sns.countplot(data_set['Category'],ax = axs[0][0],palette='YlOrBr')
sns.countplot(data_set['Region'],ax = axs[0][1],palette='Blues')
sns.countplot(data_set['Segment'],ax = axs[1][0],palette='dark:salmon_r')
sns.countplot(data_set['Ship Mode'],ax = axs[1][1],palette='Greys')
axs[0][0].set_title('Category',fontsize=20)
axs[0][1].set_title('Region',fontsize=20)
axs[1][0].set_title('Segment',fontsize=20)
axs[1][1].set_title('Ship Mode',fontsize=20)
plt.tight_layout()
# Out:
# c:\users\pamel\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\pamel\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\pamel\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\pamel\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,7))
sns.countplot(data_set['Sub-Category'], palette='Spectral_r')
plt.tight_layout()
# Out:
# c:\users\pamel\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data_set['Quantity'].value_counts()
# Out:
# 3     2409
# 2     2402
# 5     1230
# 4     1191
# 1      899
# 7      606
# 6      572
# 9      258
# 8      257
# 10      57
# 11      34
# 14      29
# 13      27
# 12      23
# Name: Quantity, dtype: int64

# %%
plt.figure(figsize=(11,7))
sns.countplot(data_set['Quantity'], palette='gist_ncar')
plt.tight_layout()
# Out:
# c:\users\pamel\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data_set['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# Louisiana                 42
# South Carolina            42
# Nevada                    39
# Nebraska                  38
# New Mexico                37
# Iowa                      30
# New Hampshire             27
# Kansas                    24
# Idaho                     21
# Montana                   15
# South Dakota              12
# Vermont                   11
# District of Columbia      10
# Maine                      8
# North Dakota               7
# West Virginia              4
# Wyoming                    1
# Name: State, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(data_set['State'], palette='twilight_shifted')
plt.xticks(rotation=270)
plt.tight_layout()
# Out:
# c:\users\pamel\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data_set['Discount'].value_counts()
# Out:
# 0.00    4798
# 0.20    3657
# 0.70     418
# 0.80     300
# 0.30     227
# 0.40     206
# 0.60     138
# 0.10      94
# 0.50      66
# 0.15      52
# 0.32      27
# 0.45      11
# Name: Discount, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.countplot(data_set['Discount'], color='purple')
plt.xticks(rotation=45)
plt.tight_layout()
# Out:
# c:\users\pamel\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Distribution Of Data**

# %%
fig, axs = plt.subplots(ncols=2, nrows = 2, figsize = (12,10))
sns.distplot(data_set['Sales'], color = 'yellow',  ax = axs[0][0])
sns.distplot(data_set['Profit'], color = 'green',  ax = axs[0][1])
sns.distplot(data_set['Quantity'], color = 'maroon',  ax = axs[1][0])
sns.distplot(data_set['Discount'], color = 'blue',  ax = axs[1][1])
axs[0][0].set_title('Sales Distribution', fontsize = 20)
axs[0][1].set_title('Profit Distribution', fontsize = 20)
axs[1][0].set_title('Quantity distribution', fontsize = 20)
axs[1][1].set_title('Discount Distribution', fontsize = 20)
plt.show()
# Out:
# c:\users\pamel\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\pamel\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\pamel\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\pamel\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data_set.hist(bins=50,figsize=(20,15),color='maroon')
plt.show()

# %% [markdown]
# **State wise Analysis**

# %%
df=data_set['State'].value_counts()
df.head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
df_states=data_set.groupby(['State'])[['Sales','Discount','Profit']].mean()
df_states.head(10)
# Out:
#                            Sales  Discount      Profit
# State
# Alabama               319.846557  0.000000   94.865989
# Arizona               157.508933  0.303571  -15.303235
# Arkansas              194.635500  0.000000   66.811452
# California            228.729451  0.072764   38.171608
# Colorado              176.418231  0.316484  -35.867351
# Connecticut           163.223866  0.007317   42.823071
# Delaware              285.948635  0.006250  103.930988
# District of Columbia  286.502000  0.000000  105.958930
# Florida               233.612815  0.299347   -8.875461
# Georgia               266.825217  0.000000   88.315453

# %%
df_state = data_set.groupby('State')['Quantity'].count().sort_values(ascending=True).plot.bar(figsize=(15,5))
plt.title('state-wise dealing',fontsize=20)
plt.xlabel('States')
plt.ylabel('Total no. of dealing')
plt.show()

# %% [markdown]
# **State-wise dealing:**
#
# California has the highest dealings in the state with almost 2K of total dealings.
#
# New York has the second highest dealings with around 1,120 of total dealings.
#
# Texas is third with almost 1K of total dealings.
#
# Wyoming has lowest dealings

# %% [markdown]
# **Profit Analysis Statewise**

# %%
df1=df_states.sort_values('Profit')

df1['Profit'].plot(kind= 'bar',figsize=(15,5),color='orange')
plt.xlabel('States')
plt.ylabel('Profit Per State')
plt.title('Profit Analysis Statewise', fontsize=20)
plt.legend()

# %% [markdown]
# **Profit Analysis Statewise:**
#
# Vermont state has Highest Profit & Ohio state has Lowest Profit

# %% [markdown]
# **Sales Analysis Statewise**

# %%
df1['Sales'].plot(kind= 'pie',figsize=(22,22),autopct='%1.1f%%',startangle=90)
plt.title('Sales Analysis Statewise', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Sales Analysis Statewise')

# %% [markdown]
# **Sales Analysis Statewise:**
#
# Highest amount of sales in Wyoming 11.8% & Lowest amount of sales in South Dakota 0.8%

# %% [markdown]
# **Discount Analysis Statewise**

# %%
df_discount = data_set.groupby('State')['Discount'].mean().sort_values(ascending=False).plot.bar(figsize=(15,5),color='violet')
plt.title('Discount Analyis Statewise',fontsize=20)
plt.xlabel('States')
plt.ylabel('Total Discount')
plt.show()

# %% [markdown]
# **Discount Analyis Statewise:**
#
# Illinois state has Highest total Discount

# %%
segment=data_set.Segment.value_counts().reset_index()
segment.columns=("Segment","Count")
segment
# Out:
#        Segment  Count
# 0     Consumer   5191
# 1    Corporate   3020
# 2  Home Office   1783

# %%
plt.pie(x="Count",labels="Segment",data=segment,radius=2,autopct="%.2f",pctdistance=0.4)
# Out:
# ([<matplotlib.patches.Wedge at 0x208b71fdf70>,
#   <matplotlib.patches.Wedge at 0x208b768ff70>,
#   <matplotlib.patches.Wedge at 0x208b7689520>],
#  [Text(-0.13408036713364035, 2.1959103932422446, 'Consumer'),
#   Text(-1.0537686579632295, -1.9312098838537397, 'Corporate'),
#   Text(1.8633972391176687, -1.1695087555245793, 'Home Office')],
#  [Text(-0.048756497139505584, 0.798512870269907, '51.94'),
#   Text(-0.3831886028957198, -0.7022581395831781, '30.22'),
#   Text(0.6775989960427886, -0.425275911099847, '17.84')])

# %% [markdown]
# **Top 5 cities by Sales,Profit,Discount**

# %%
total_sales = data_set.groupby('City')['Sales'].sum()

top_5_cities = total_sales.sort_values(ascending = False).iloc[0:5]
top_5_cities.plot(kind = 'barh')
plt.title('Top 5 cities by sales',fontsize=15)
plt.xticks(rotation=270)
plt.xlabel('Sales')
plt.show()

# %%
total_profit = data_set.groupby('City')['Profit'].sum()

top_5_cities = total_profit.sort_values(ascending= False).iloc[0:5]
top_5_cities.plot(kind = 'barh')
plt.title('Top 5 cities by Profit',fontsize=15)
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %%
total_profit = data_set.groupby('City')['Discount'].sum()

top_5_cities = total_profit.sort_values(ascending= False).iloc[0:5]
top_5_cities.plot(kind = 'bar')
plt.title('Top 5 cities by Discount',fontsize=15)
plt.xticks(rotation=0)
plt.ylabel('Discount')
# Out:
# Text(0, 0.5, 'Discount')

# %% [markdown]
# **Sales by Region**

# %%
total_sales = data_set.groupby('Region')['Sales'].sum()

region_sales = total_sales.sort_values(ascending = False).iloc[0:4]
region_sales.plot(kind ='barh')
plt.title('Sales by Region',fontsize=15)
plt.xlabel('Sales')
plt.show()

# %% [markdown]
# **Sales by Segment**

# %%
total_profit = data_set.groupby('Segment')['Sales'].sum()

segment_sales = total_profit.sort_values(ascending= False).iloc[0:4]
segment_sales.plot(kind = 'bar',fontsize=10)
plt.title('Sales by Segment')
plt.xticks(rotation=0)
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
sns.lineplot(x='Sales',y='Profit',data = data_set)
plt.show()

# %%
sns.lineplot(x='Discount',y='Profit',data = data_set)
plt.show()

# %% [markdown]
# **From above we conclude that, Product sales increases with increase in Discounts but Profit decreases.**

# %% [markdown]
# **Average profit by Discount**

# %%
ax = sns.barplot(x = 'Discount', y = 'Profit', data = data_set, palette = 'crest', ci = None )
ax.set_title('Average profit by Discount', fontsize = 18)
plt.axhline(y = data_set['Profit'].mean(), linestyle='--')
plt.axhline(y = 0, linestyle='-')
plt.xlabel("")
plt.ylabel("Average profit")
plt.show()

# %% [markdown]
# **Average Sales by Discount**

# %%
ax = sns.barplot(x = 'Discount', y = 'Sales', data = data_set, palette = 'rainbow', ci = None )
ax.set_title('Average Sales by Discount', fontsize = 18)
plt.axhline(y = data_set['Sales'].mean(),linestyle='--')
plt.axhline(y = 0, linestyle='-')
plt.xlabel("")
plt.ylabel("Average Sales")
plt.show()

# %% [markdown]
# **From above we can see that, sales made with less than 20% discounts are more profitable.**

# %% [markdown]
# **Average Sales and profit/loss for Region**

# %%
df_region = data_set.groupby(['Region'])[['Sales','Profit']].mean()
df_region.sort_values('Profit', ascending = False)[['Sales', 'Profit']].plot(kind = 'bar',figsize = (15, 5),color=['teal','blue'])
plt.ylabel('Average Profit/Loss and Sales')
plt.xlabel('Region')
plt.xticks(rotation=45)
plt.title('Average Sales and Profit/Loss for Regions', fontsize = 15)
plt.show()

# %%
df_region = data_set.groupby(['Category'])[['Sales','Profit']].mean()
df_region.sort_values('Profit', ascending = False)[['Sales', 'Profit']].plot(kind = 'bar',figsize = (15, 5),color=['green','seagreen'])
plt.ylabel('Average Profit/Loss and Sales')
plt.xlabel('Region')
plt.xticks(rotation=25)
plt.title('Average Sales and Profit/Loss for Category', fontsize = 10)
plt.show()

# %% [markdown]
# THANK YOU
